# %% [markdown]
# # Titanic Machine Learning Project
#
# ### Add Imports

# %%
#Imports

#data imports
import pandas as pd
import numpy as np

#machine learning imports
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

#visualization imports
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Create the Dataframe

# %%
data = pd.read_csv("data/titanic.csv")
data.info()
print(data.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### Fill in missing ages

# %%
def fill_missing_ages(df):
    age_fill_map = {}
    for pclass in df["Pclass"].unique():
        if pclass not in age_fill_map:
            age_fill_map[pclass] = df[df["Pclass"] == pclass]["Age"].median()

    df["Age"] = df.apply(lambda row: age_fill_map[row["Pclass"]] if pd.isnull(row["Age"]) else row["Age"], axis=1)

# %% [markdown]
# ### Data Cleaning and Feature Engineering

# %%
def preprocess_data(df):
    # Delete all Columns/data aren't relevant for what we're trying to accomplish
    df.drop(columns=["PassengerId", "Name", "Ticket", "Cabin", "Embarked"], inplace=True)

    #Fill in missing data from Embarked
    # df["Embarked"].fillna("S", inplace=True)
    # df.drop(columns=["Embarked"], inplace=True)
    
    fill_missing_ages(df)

    # Convert Gender to binary for machine learning
    df["Sex"] = df["Sex"].map({"male":1, "female":0})

    # Feature Engineering: Creating new columns in our data to help enhance the model
    df["FamilySize"] = df["SibSp"] + df["Parch"]
    df["IsAlone"] = np.where(df["FamilySize"] == 0, 1, 0)
    df["FareBin"] = pd.qcut(df["Fare"], 4, labels=False)
    df["AgeBin"] = pd.cut(df["Age"], bins=[0,12,20,40,60, np.inf], labels=False)

    return df

# %% [markdown]
# ### Update and check the Data

# %%
data = preprocess_data(data)

#display(data.head(10))
display(data.sample(10))
#display(data.tail(10))
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch      Fare  FamilySize  IsAlone  \
# 285         0       3    1  33.0      0      0    8.6625           0        1
# 550         1       1    1  17.0      0      2  110.8833           2        0
# 883         0       2    1  28.0      0      0   10.5000           0        1
# 143         0       3    1  19.0      0      0    6.7500           0        1
# 275         1       1    0  63.0      1      0   77.9583           1        0
# 93          0       3    1  26.0      1      2   20.5750           3        0
# 210         0       3    1  24.0      0      0    7.0500           0        1
# 419         0       3    0  10.0      0      2   24.1500           2        0
# 40          0       3    0  40.0      1      0    9.4750           1        0
# 812         0       2    1  35.0      0      0   10.5000           0        1
#
#      FareBin  AgeBin
# 285        1       2
# 550        3       1
# 883        1       2
# 143        0       1
# 275        3       4
# 93         2       2
# 210        0       2
# 419        2       0
# 40         1       2
# 812        1       2

# %% [markdown]
# ### Create Features / Target Variables (Make Flashcards)

# %%
X = data.drop(columns=["Survived"])
y = data["Survived"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# ### ML Preprocessing
# When we take our data and we make sure it's numerically formatted for the model to understand

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### Hyperparameter Tuning - KNN

# %%
def tune_model(X_train, y_train):
    param_grid = {
        "n_neighbors":range(1,21),
        "metric" : ["euclidean", "manhetten", "minkowski"],
        "weights" : ["uniform", "distance"]
    }

    model = KNeighborsClassifier()
    grid_search = GridSearchCV(model, param_grid, cv=5, n_jobs=-1)
    grid_search.fit(X_train, y_train)
    return grid_search.best_estimator_

best_model = tune_model(X_train, y_train)
# Out:
# c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py:516: FitFailedWarning:
# 490 fits failed out of a total of 1470.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'russellrao', 'haversine', 'braycurtis', 'sokalsneath', 'precomputed', 'canberra', 'sokalmichener', 'nan_euclidean', 'dice', 'chebyshev', 'rogerstanimoto', 'p', 'cosine', 'cityblock', 'hamming', 'infinity', 'jaccard', 'l2', 'pyfunc', 'l1', 'sqeuclidean', 'correlation', 'manhattan', 'yule', 'minkowski', 'mahalanobis', 'seuclidean', 'euclidean'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'manhetten' instead.
#
# --------------------------------------------------------------------------------
# 48 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'rogerstanimoto', 'sokalmichener', 'euclidean', 'sokalsneath', 'correlation', 'hamming', 'yule', 'braycurtis', 'russellrao', 'minkowski', 'sqeuclidean', 'chebyshev', 'p', 'manhattan', 'precomputed', 'haversine', 'pyfunc', 'l1', 'l2', 'jaccard', 'mahalanobis', 'cosine', 'seuclidean', 'dice', 'canberra', 'nan_euclidean', 'infinity', 'cityblock'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'manhetten' instead.
#
# --------------------------------------------------------------------------------
# 32 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'cosine', 'yule', 'sqeuclidean', 'haversine', 'precomputed', 'seuclidean', 'manhattan', 'p', 'russellrao', 'dice', 'l1', 'l2', 'sokalmichener', 'chebyshev', 'sokalsneath', 'infinity', 'jaccard', 'mahalanobis', 'canberra', 'pyfunc', 'euclidean', 'hamming', 'cityblock', 'braycurtis', 'correlation', 'nan_euclidean', 'minkowski', 'rogerstanimoto'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'manhetten' instead.
#
# --------------------------------------------------------------------------------
# 32 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'sokalmichener', 'p', 'cosine', 'yule', 'minkowski', 'braycurtis', 'canberra', 'precomputed', 'hamming', 'l2', 'dice', 'haversine', 'correlation', 'infinity', 'rogerstanimoto', 'chebyshev', 'l1', 'nan_euclidean', 'pyfunc', 'manhattan', 'sokalsneath', 'euclidean', 'sqeuclidean', 'cityblock', 'mahalanobis', 'russellrao', 'jaccard', 'seuclidean'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'manhetten' instead.
#
# --------------------------------------------------------------------------------
# 32 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'manhattan', 'canberra', 'cityblock', 'mahalanobis', 'braycurtis', 'infinity', 'seuclidean', 'chebyshev', 'l1', 'pyfunc', 'nan_euclidean', 'l2', 'yule', 'precomputed', 'jaccard', 'minkowski', 'p', 'haversine', 'correlation', 'sqeuclidean', 'russellrao', 'dice', 'hamming', 'sokalsneath', 'sokalmichener', 'cosine', 'euclidean', 'rogerstanimoto'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'manhetten' instead.
#
# --------------------------------------------------------------------------------
# 32 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'jaccard', 'sokalmichener', 'precomputed', 'hamming', 'chebyshev', 'l1', 'sqeuclidean', 'cityblock', 'rogerstanimoto', 'correlation', 'mahalanobis', 'cosine', 'haversine', 'pyfunc', 'yule', 'infinity', 'braycurtis', 'seuclidean', 'l2', 'nan_euclidean', 'dice', 'canberra', 'manhattan', 'p', 'minkowski', 'sokalsneath', 'russellrao', 'euclidean'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'manhetten' instead.
#
# --------------------------------------------------------------------------------
# 32 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'sokalsneath', 'dice', 'cityblock', 'seuclidean', 'sokalmichener', 'minkowski', 'sqeuclidean', 'nan_euclidean', 'precomputed', 'mahalanobis', 'russellrao', 'canberra', 'p', 'chebyshev', 'braycurtis', 'yule', 'correlation', 'haversine', 'l2', 'manhattan', 'jaccard', 'hamming', 'l1', 'pyfunc', 'cosine', 'infinity', 'rogerstanimoto', 'euclidean'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'manhetten' instead.
#
# --------------------------------------------------------------------------------
# 32 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'precomputed', 'braycurtis', 'cityblock', 'mahalanobis', 'yule', 'euclidean', 'minkowski', 'correlation', 'cosine', 'nan_euclidean', 'sqeuclidean', 'sokalsneath', 'infinity', 'sokalmichener', 'l1', 'russellrao', 'jaccard', 'pyfunc', 'hamming', 'canberra', 'rogerstanimoto', 'seuclidean', 'dice', 'p', 'manhattan', 'l2', 'chebyshev', 'haversine'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'manhetten' instead.
#
# --------------------------------------------------------------------------------
# 32 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'p', 'sokalsneath', 'mahalanobis', 'sokalmichener', 'pyfunc', 'euclidean', 'haversine', 'dice', 'l1', 'l2', 'chebyshev', 'manhattan', 'braycurtis', 'correlation', 'precomputed', 'nan_euclidean', 'rogerstanimoto', 'seuclidean', 'hamming', 'cosine', 'russellrao', 'yule', 'jaccard', 'infinity', 'canberra', 'minkowski', 'sqeuclidean', 'cityblock'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'manhetten' instead.
#
# --------------------------------------------------------------------------------
# 32 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'braycurtis', 'l2', 'cityblock', 'infinity', 'rogerstanimoto', 'sqeuclidean', 'yule', 'cosine', 'jaccard', 'chebyshev', 'haversine', 'seuclidean', 'euclidean', 'manhattan', 'pyfunc', 'canberra', 'l1', 'mahalanobis', 'dice', 'minkowski', 'correlation', 'hamming', 'nan_euclidean', 'russellrao', 'sokalsneath', 'p', 'sokalmichener', 'precomputed'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'manhetten' instead.
#
# --------------------------------------------------------------------------------
# 32 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'minkowski', 'cityblock', 'braycurtis', 'euclidean', 'dice', 'sokalsneath', 'nan_euclidean', 'yule', 'precomputed', 'mahalanobis', 'p', 'chebyshev', 'cosine', 'pyfunc', 'russellrao', 'manhattan', 'hamming', 'sqeuclidean', 'l2', 'correlation', 'l1', 'canberra', 'rogerstanimoto', 'infinity', 'haversine', 'jaccard', 'sokalmichener', 'seuclidean'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'manhetten' instead.
#
# --------------------------------------------------------------------------------
# 32 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'precomputed', 'cityblock', 'rogerstanimoto', 'hamming', 'sokalmichener', 'sqeuclidean', 'dice', 'yule', 'russellrao', 'minkowski', 'haversine', 'braycurtis', 'correlation', 'jaccard', 'chebyshev', 'l1', 'euclidean', 'pyfunc', 'canberra', 'manhattan', 'infinity', 'seuclidean', 'sokalsneath', 'nan_euclidean', 'mahalanobis', 'cosine', 'l2', 'p'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'manhetten' instead.
#
# --------------------------------------------------------------------------------
# 32 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'p', 'manhattan', 'infinity', 'cityblock', 'haversine', 'minkowski', 'sokalmichener', 'seuclidean', 'canberra', 'russellrao', 'euclidean', 'cosine', 'sqeuclidean', 'chebyshev', 'yule', 'rogerstanimoto', 'precomputed', 'mahalanobis', 'jaccard', 'hamming', 'nan_euclidean', 'dice', 'pyfunc', 'correlation', 'braycurtis', 'l2', 'l1', 'sokalsneath'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'manhetten' instead.
#
# --------------------------------------------------------------------------------
# 32 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'euclidean', 'chebyshev', 'sqeuclidean', 'yule', 'correlation', 'haversine', 'l1', 'l2', 'jaccard', 'mahalanobis', 'dice', 'seuclidean', 'braycurtis', 'rogerstanimoto', 'nan_euclidean', 'cityblock', 'precomputed', 'manhattan', 'sokalsneath', 'p', 'russellrao', 'hamming', 'canberra', 'infinity', 'cosine', 'sokalmichener', 'minkowski', 'pyfunc'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'manhetten' instead.
#
# --------------------------------------------------------------------------------
# 32 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'correlation', 'infinity', 'rogerstanimoto', 'minkowski', 'cosine', 'braycurtis', 'jaccard', 'sokalsneath', 'precomputed', 'l1', 'dice', 'sokalmichener', 'nan_euclidean', 'euclidean', 'sqeuclidean', 'canberra', 'seuclidean', 'russellrao', 'p', 'mahalanobis', 'haversine', 'l2', 'yule', 'manhattan', 'chebyshev', 'hamming', 'pyfunc', 'cityblock'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'manhetten' instead.
#
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'manhattan', 'chebyshev', 'euclidean', 'rogerstanimoto', 'dice', 'nan_euclidean', 'l2', 'cityblock', 'russellrao', 'haversine', 'hamming', 'pyfunc', 'canberra', 'jaccard', 'l1', 'infinity', 'p', 'cosine', 'mahalanobis', 'minkowski', 'yule', 'sqeuclidean', 'sokalmichener', 'sokalsneath', 'correlation', 'braycurtis', 'precomputed', 'seuclidean'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'manhetten' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\dslem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_search.py:1135: UserWarning: One or more of the test scores are non-finite: [0.77100213 0.77100213 0.78896869 0.77547974 0.82344294 0.80693525
#  0.82343171 0.80845023 0.82342049 0.81445405 0.82641679 0.82042419
#  0.83692066 0.82792055 0.82493547 0.82193918 0.82491303 0.82493547
#  0.8278981  0.82340927 0.82192795 0.8219504  0.82642801 0.82342049
#  0.81445405 0.82192795 0.8189541  0.82339805 0.80994277 0.81593536
#  0.80845023 0.82190551 0.80994277 0.81892044 0.80089777 0.81892044
#  0.79342386 0.81743912 0.79640893 0.81295029 0.79041634 0.81295029
#  0.79042756 0.81144653 0.79043878 0.80995399 0.78143867 0.80694647
#  0.78294243 0.80694647 0.78442375 0.80244641 0.78891258 0.80395017
#  0.78742004 0.80095388 0.78742004 0.79945012 0.79041634 0.80094266
#  0.7919201  0.7994389  0.78743126 0.79794636 0.79794636 0.79794636
#  0.79793514 0.79496128 0.79643138 0.79496128 0.7964426  0.79795758
#  0.79343508 0.79646504 0.79194254 0.79497251 0.79193132 0.79497251
#  0.79193132 0.79646504 0.79043878 0.79646504 0.79043878 0.79646504
#  0.78894625 0.79496128 0.78894625 0.79346875 0.78894625 0.79496128
#  0.78894625 0.79645382 0.78894625 0.79346875 0.78894625 0.79196499
#  0.78894625 0.79346875        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan 0.77100213 0.77100213
#  0.78896869 0.77547974 0.82344294 0.80693525 0.82343171 0.80845023
#  0.82342049 0.81445405 0.82641679 0.82042419 0.83692066 0.82792055
#  0.82493547 0.82193918 0.82491303 0.82493547 0.8278981  0.82340927
#  0.82192795 0.8219504  0.82642801 0.82342049 0.81445405 0.82192795
#  0.8189541  0.82339805 0.80994277 0.81593536 0.80845023 0.82190551
#  0.80994277 0.81892044 0.80089777 0.81892044 0.79342386 0.81743912
#  0.79640893 0.81295029 0.79041634 0.81295029 0.79042756 0.81144653
#  0.79043878 0.80995399 0.78143867 0.80694647 0.78294243 0.80694647
#  0.78442375 0.80244641 0.78891258 0.80395017 0.78742004 0.80095388
#  0.78742004 0.79945012 0.79041634 0.80094266 0.7919201  0.7994389
#  0.78743126 0.79794636 0.79794636 0.79794636 0.79793514 0.79496128
#  0.79643138 0.79496128 0.7964426  0.79795758 0.79343508 0.79646504
#  0.79194254 0.79497251 0.79193132 0.79497251 0.79193132 0.79646504
#  0.79043878 0.79646504 0.79043878 0.79646504 0.78894625 0.79496128
#  0.78894625 0.79346875 0.78894625 0.79496128 0.78894625 0.79645382
#  0.78894625 0.79346875 0.78894625 0.79196499 0.78894625 0.79346875]
#   warnings.warn(

# %% [markdown]
# ### Predictions and Evaluate

# %%
def evaluate_model(model, X_test, y_test):
    prediction = model.predict(X_test)
    accuracy = accuracy_score(y_test, prediction)
    matrix = confusion_matrix(y_test, prediction)
    return accuracy, matrix

accuracy, matrix = evaluate_model(best_model, X_test, y_test)

# %%
print(f'Accuracy: {accuracy*100:.2f}%')
print(f'Confusion Matrix:')
print(matrix)
# Out:
# Accuracy: 80.27%
# Confusion Matrix:
# [[115  19]
#  [ 25  64]]

# %%
def plot_model(matrix):
    plt.figure(figsize=(10,7))
    sns.heatmap(matrix, annot=True, fmt="d", xticklabels=["Survived", "Not Survived"], yticklabels=["Survived", "Not Survived"])
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted Values")
    plt.ylabel("True Values")
    plt.show()

plot_model(matrix)
